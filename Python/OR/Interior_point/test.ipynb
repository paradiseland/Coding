# %%
import numpy as np
import numdifftools as nd

# %%
f = nd.Derivative(np.exp, full_output=True)

# %%
def e(x):
    return np.exp(-x[0])+np.exp(-2*x[1])

# %%
H = nd.Hessian(e)

# %%
def f(X):
    pass
    return X[0]+X[1]

# %%
f([2,3])
# Out:
# 5

# %%
[1e-5]*5
# Out:
# [1e-05, 1e-05, 1e-05, 1e-05, 1e-05]

# %%
a = np.array(([2,5],[3,2]))
b = np.array(([1,0]))
