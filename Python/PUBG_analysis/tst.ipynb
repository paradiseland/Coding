# %%
"""
preprocess the PUBG data.
"""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
AGG = pd.read_csv("./pubg-match-deaths/aggregate/agg_match_stats_0.csv")

# %%
AGG.head()
# Out:
#                        date  game_size  \
# 0  2017-11-26T20:59:40+0000         37
# 1  2017-11-26T20:59:40+0000         37
# 2  2017-11-26T20:59:40+0000         37
# 3  2017-11-26T20:59:40+0000         37
# 4  2017-11-26T20:59:40+0000         37
#
#                                             match_id match_mode  party_size  \
# 0  2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp           2
# 1  2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp           2
# 2  2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp           2
# 3  2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp           2
# 4  2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp           2
#
#    player_assists  player_dbno  player_dist_ride  player_dist_walk  \
# 0               0            1        2870.72400       1784.847780
# 1               0            1        2938.40723       1756.079710
# ...

# %%
AGG_matchidvalue = AGG['match_id'].value_counts()
index_g99 = AGG_matchidvalue.index[AGG_matchidvalue ==100]
AGG_select = AGG[AGG['match_id'].isin(index_g99)]
AGG_select
# Out:
#                               date  game_size  \
# 1061      2017-11-04T07:29:45+0000         50
# 1062      2017-11-04T07:29:45+0000         50
# 1063      2017-11-04T07:29:45+0000         50
# 1064      2017-11-04T07:29:45+0000         50
# 1065      2017-11-04T07:29:45+0000         50
# ...                            ...        ...
# 13845342  2017-12-03T01:19:20+0000         50
# 13845343  2017-12-03T01:19:20+0000         50
# 13845344  2017-12-03T01:19:20+0000         50
# 13845345  2017-12-03T01:19:20+0000         50
# 13845346  2017-12-03T01:19:20+0000         50
#
#                                                    match_id match_mode  \
# 1061      2U4GBNA0YmnXxPYMxq8uh3IZ_R74uPmFVfhHlxf6M3-PzR...        tpp
# 1062      2U4GBNA0YmnXxPYMxq8uh3IZ_R74uPmFVfhHlxf6M3-PzR...        tpp
# 1063      2U4GBNA0YmnXxPYMxq8uh3IZ_R74uPmFVfhHlxf6M3-PzR...        tpp
# 1064      2U4GBNA0YmnXxPYMxq8uh3IZ_R74uPmFVfhHlxf6M3-PzR...        tpp
# ...

# %%
AGG_select.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
# Out:
#                               date  game_size  \
# 1061      2017-11-04T07:29:45+0000         50
# 1062      2017-11-04T07:29:45+0000         50
# 1063      2017-11-04T07:29:45+0000         50
# 1064      2017-11-04T07:29:45+0000         50
# 1065      2017-11-04T07:29:45+0000         50
# ...                            ...        ...
# 13845342  2017-12-03T01:19:20+0000         50
# 13845343  2017-12-03T01:19:20+0000         50
# 13845344  2017-12-03T01:19:20+0000         50
# 13845345  2017-12-03T01:19:20+0000         50
# 13845346  2017-12-03T01:19:20+0000         50
#
#                                                    match_id match_mode  \
# 1061      2U4GBNA0YmnXxPYMxq8uh3IZ_R74uPmFVfhHlxf6M3-PzR...        tpp
# 1062      2U4GBNA0YmnXxPYMxq8uh3IZ_R74uPmFVfhHlxf6M3-PzR...        tpp
# 1063      2U4GBNA0YmnXxPYMxq8uh3IZ_R74uPmFVfhHlxf6M3-PzR...        tpp
# 1064      2U4GBNA0YmnXxPYMxq8uh3IZ_R74uPmFVfhHlxf6M3-PzR...        tpp
# ...

# %%
AGG_Selected = AGG_select

# %%
AGG_Selected = AGG_Selected.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# drop the duplicate
AGG_Selected = AGG_Selected.drop_duplicates(inplace=True)

# add a column of won or not
AGG_Selected['won'] = AGG_Selected['team_placement'] == 1

# add a column of drove or not
AGG_Selected['drove'] = AGG_Selected['player_dist_ride'] != 0
# Out:
# C:\Python\Python_3.6.8\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-c8e27c4a4061> in <module>
#       5
#       6 # add a column of won or not
# ----> 7 AGG_Selected['won'] = AGG_Selected['team_placement'] == 1
#       8
#       9 # add a column of drove or not
#
# TypeError: 'NoneType' object is not subscriptable

# %%
AGG_Selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418700 entries, 1061 to 13845346
# Data columns (total 17 columns):
# date                   418700 non-null object
# game_size              418700 non-null int64
# match_id               418700 non-null object
# match_mode             418700 non-null object
# party_size             418700 non-null int64
# player_assists         418700 non-null int64
# player_dbno            418700 non-null int64
# player_dist_ride       418700 non-null float64
# player_dist_walk       418700 non-null float64
# player_dmg             418700 non-null int64
# player_kills           418700 non-null int64
# player_name            418220 non-null object
# player_survive_time    418700 non-null float64
# team_id                418700 non-null int64
# team_placement         418700 non-null int64
# won                    418700 non-null bool
# drove                  418700 non-null bool
# dtypes: bool(2), float64(3), int64(8), object(4)
# ...

# %%
AGG_Selected.head()
# Out:
#                           date  game_size  \
# 1061  2017-11-04T07:29:45+0000         50
# 1062  2017-11-04T07:29:45+0000         50
# 1063  2017-11-04T07:29:45+0000         50
# 1064  2017-11-04T07:29:45+0000         50
# 1065  2017-11-04T07:29:45+0000         50
#
#                                                match_id match_mode  \
# 1061  2U4GBNA0YmnXxPYMxq8uh3IZ_R74uPmFVfhHlxf6M3-PzR...        tpp
# 1062  2U4GBNA0YmnXxPYMxq8uh3IZ_R74uPmFVfhHlxf6M3-PzR...        tpp
# 1063  2U4GBNA0YmnXxPYMxq8uh3IZ_R74uPmFVfhHlxf6M3-PzR...        tpp
# 1064  2U4GBNA0YmnXxPYMxq8uh3IZ_R74uPmFVfhHlxf6M3-PzR...        tpp
# 1065  2U4GBNA0YmnXxPYMxq8uh3IZ_R74uPmFVfhHlxf6M3-PzR...        tpp
#
#       party_size  player_assists  player_dbno  player_dist_ride  \
# 1061           2               0            1        4984.54900
# 1062           2               1            0        5960.46436
# 1063           2               0            0           0.00000
# ...

# %%
AGG_Selected.to_csv('agg1.csv')

# %%
DEATH = pd.read_csv("./pubg-match-deaths/deaths/kill_match_stats_final_0.csv")

# %%
DEATH.head()
# Out:
#       killed_by       killer_name  killer_placement  killer_position_x  \
# 0       Grenade   KrazyPortuguese               5.0          657725.10
# 1        SCAR-L  nide2Bxiaojiejie              31.0           93091.37
# 2          S686          Ascholes              43.0          366921.40
# 3  Down and Out        Weirdo7777               9.0          472014.20
# 4          M416         Solayuki1               9.0          473357.80
#
#    killer_position_y      map  \
# 0           146275.2  MIRAMAR
# 1           722236.4  MIRAMAR
# 2           421623.9  MIRAMAR
# 3           313274.8  MIRAMAR
# 4           318340.5  MIRAMAR
#
#                                             match_id  time      victim_name  \
# 0  2U4GBNA0YmnLSqvEycnTjo-KT000vfUnhSA2vfVhVPe1QB...   823  KrazyPortuguese
# 1  2U4GBNA0YmnLSqvEycnTjo-KT000vfUnhSA2vfVhVPe1QB...   194      X3evolution
# 2  2U4GBNA0YmnLSqvEycnTjo-KT000vfUnhSA2vfVhVPe1QB...   103          CtrlZee
# ...

# %%
DEATH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13426348 entries, 0 to 13426347
# Data columns (total 12 columns):
# killed_by            object
# killer_name          object
# killer_placement     float64
# killer_position_x    float64
# killer_position_y    float64
# map                  object
# match_id             object
# time                 int64
# victim_name          object
# victim_placement     float64
# victim_position_x    float64
# victim_position_y    float64
# dtypes: float64(6), int64(1), object(5)
# memory usage: 1.2+ GB

# %%
DEATH_MatchIdValue = DEATH['match_id'].value_counts()

# %%
indDEATH_gt99 = DEATH_MatchIdValue.index[DEATH_MatchIdValue >= 98]
DEATH_Selected = DEATH[DEATH['match_id'].isin(indDEATH_gt99)]
DEATH_Selected.head()
# Out:
#         killed_by  killer_name  killer_placement  killer_position_x  \
# 179  Down and Out    Malcolm_x               9.0           496989.8
# 180         M16A4    Malcolm_x               9.0           496989.8
# 181           AKM       G_Berg               7.0           460416.7
# 182           AKM  Lukesnake17              20.0           488034.1
# 183           SKS     AlooGobi               2.0           501062.9
#
#      killer_position_y      map  \
# 179           312569.7  ERANGEL
# 180           312569.7  ERANGEL
# 181           414748.8  ERANGEL
# 182           347220.3  ERANGEL
# 183           425078.6  ERANGEL
#
#                                               match_id  time  victim_name  \
# 179  2U4GBNA0YmnRe95wOy7kuweIkuZo5Roa0WjNZsgboi2gzz...  1035      Relugar
# 180  2U4GBNA0YmnRe95wOy7kuweIkuZo5Roa0WjNZsgboi2gzz...  1035  LiPoBattery
# 181  2U4GBNA0YmnRe95wOy7kuweIkuZo5Roa0WjNZsgboi2gzz...  1422     cornsour
# ...

# %%
DEATH_Selected
# Out:
#              killed_by    killer_name  killer_placement  killer_position_x  \
# 179       Down and Out      Malcolm_x               9.0           496989.8
# 180              M16A4      Malcolm_x               9.0           496989.8
# 181                AKM         G_Berg               7.0           460416.7
# 182                AKM    Lukesnake17              20.0           488034.1
# 183                SKS       AlooGobi               2.0           501062.9
# ...                ...            ...               ...                ...
# 13423826         S1897       Bananaas              48.0           635834.9
# 13423827          M416         wenbin              28.0           637016.6
# 13423828          M416     baozouD-ST              13.0           492950.4
# 13423829         Punch       Thor2Ebe              65.0           218668.8
# 13423830           AKM  douyu-3465817              43.0           636673.6
#
#           killer_position_y      map  \
# ...

# %%
DEATH_Selected.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# drop the duplicate
DEATH_Selected.drop_duplicates(inplace=True)
# Out:
# C:\Python\Python_3.6.8\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
DEATH_Selected
# Out:
#              killed_by    killer_name  killer_placement  killer_position_x  \
# 179       Down and Out      Malcolm_x               9.0           496989.8
# 180              M16A4      Malcolm_x               9.0           496989.8
# 181                AKM         G_Berg               7.0           460416.7
# 182                AKM    Lukesnake17              20.0           488034.1
# 183                SKS       AlooGobi               2.0           501062.9
# ...                ...            ...               ...                ...
# 13423826         S1897       Bananaas              48.0           635834.9
# 13423827          M416         wenbin              28.0           637016.6
# 13423828          M416     baozouD-ST              13.0           492950.4
# 13423829         Punch       Thor2Ebe              65.0           218668.8
# 13423830           AKM  douyu-3465817              43.0           636673.6
#
#           killer_position_y      map  \
# ...

# %%
DEATH_Selected['kill_distance'] = np.sqrt((DEATH_Selected['killer_position_x']-DEATH_Selected['victim_position_x'])**2+(DEATH_Selected['killer_position_y']-DEATH_Selected['victim_position_y'])**2)
# Out:
# C:\Python\Python_3.6.8\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
DEATH_Selected['kill_distance'].sort_values()
# Out:
# 3177292     0.0
# 9113648     0.0
# 10105573    0.0
# 11894408    0.0
# 11990589    0.0
#            ...
# 13423361    NaN
# 13423362    NaN
# 13423386    NaN
# 13423774    NaN
# 13423790    NaN
# Name: kill_distance, Length: 642554, dtype: float64

# %%
DEATH_Selected['kill_distance']
# Out:
# 179         18962.626970
# 180         19429.319358
# 181           680.123290
# 182           730.400233
# 183         12340.478131
#                 ...
# 13423826      864.260314
# 13423827     1561.701550
# 13423828      329.001945
# 13423829       88.708286
# 13423830     3788.362724
# Name: kill_distance, Length: 642554, dtype: float64

# %%
DEATH_Selected.shape
# Out:
# (642554, 13)

# %%
DEATH_Selected = DEATH_Selected.drop(DEATH_Selected[DEATH_Selected['kill_distance']>=100000].index)

# %%
DEATH_Selected.shape
# Out:
# (642554, 13)

# %%
DEATH_Selected[DEATH_Selected['kill_distance']>=100000]
# Out:
#            killed_by       killer_name  killer_placement  killer_position_x  \
# 228            Punch    ClaudeAuditore              19.0           364248.1
# 234           Sickle         Sun-aiyou              35.0           362384.9
# 1733      Hit by Car      AnalCream228              23.0           423190.4
# 11152       Bluezone            IKEBOU              19.0                0.0
# 11175          Punch        kuchaxiong              21.0           159444.8
# ...              ...               ...               ...                ...
# 13415571       Punch            Bier45               1.0           646355.0
# 13423316       M16A4  ZQ_DHN_152574437               9.0           554331.2
# 13423753  Hit by Car            NingGp              36.0           477577.1
# 13423781       Punch         Watsonboy              22.0           235715.2
# 13423819         P92         Watsonboy              22.0           233057.5
#
#           killer_position_y      map  \
# ...

# %%
killer_times = DEATH_Selected['killer_name'].value_counts()

# %%
DEATH_Selected['killer_name']
# Out:
# 179             Malcolm_x
# 180             Malcolm_x
# 181                G_Berg
# 182           Lukesnake17
# 183              AlooGobi
#                 ...
# 13423826         Bananaas
# 13423827           wenbin
# 13423828       baozouD-ST
# 13423829         Thor2Ebe
# 13423830    douyu-3465817
# Name: killer_name, Length: 642554, dtype: object

# %%
DEATH_Selected['killer_name'].isin(killer_times[killer_times>30].index)
# Out:
# 179         False
# 180         False
# 181         False
# 182         False
# 183         False
#             ...
# 13423826    False
# 13423827    False
# 13423828    False
# 13423829    False
# 13423830    False
# Name: killer_name, Length: 642554, dtype: bool

# %%
DEATH_Selected = DEATH_Selected.drop(DEATH_Selected[DEATH_Selected['killer_name'].isin(killer_times[killer_times>30].index)].index)

# %%
killer_times[killer_times>=30].index
# Out:
# Index(['#unknown', 'z1148139722', 'qcsicknasty', 'QQqun-608179539',
#        'WG_Qun-326373092', 'CHENKEYU521', '6l8-I34-8O0-g9un', 'yy555333_',
#        'sania11174', 'vx-zhoushiwei', 'Fans-2777777965q', 'Roobydooble',
#        'Qqun-648314099', 'Ovn_629333804', 'WG-301323278_', 'Carebeers',
#        'Eighteen_shiba', 'MnH-Over', 'Implacity', 'try_01113', 'MartyrLOL',
#        '67_627445_9', 'HuoCaiRen_No_1', 'CHN-PEN1S', 'LE55777_VX',
#        '6oB2-5-5-7-7-3', 'DouYuTv_Corsair', 'OrangeCat-Batian',
#        'NideMingzi-Shi', 'WG_Q3002737275', 'zhibaba123456', 'XIQWUDI',
#        'Drea1112', 'SNlPER_', 'Yy_5908_xlaojun', 'guobabaa', 'hotgamergirl18',
#        'WGqun-2920293', 'God7Kung-', 'fanxiaofei', 'Guppa', 'Paratrooper_',
#        'qingbiexiangyu', 'Lattuer', 'LingBB20', 'Qqun_648314099', 'seanesl',
#        'wG-QUN187264349', 'YouZ1', 'LRHandsomeguy', 'HUANGJIAMADELI',
#        'KISS2008', 'badaree', 'wujing6', 'Veryhotguy', 'iDreamTV',
# ...

# %%
DEATH_Selected['killer_name'].isin(killer_times[killer_times>30].index)
# Out:
# 179         False
# 180         False
# 181         False
# 182         False
# 183         False
#             ...
# 13423826    False
# 13423827    False
# 13423828    False
# 13423829    False
# 13423830    False
# Name: killer_name, Length: 642554, dtype: bool

# %%
DEATH_Selected[DEATH_Selected['killer_name'].isin(killer_times[killer_times>30].index)]
# Out:
#              killed_by killer_name  killer_placement  killer_position_x  \
# 10606     Down and Out    #unknown              34.0           617962.3
# 10648           SCAR-L    #unknown               1.0           521221.4
# 10666        Micro UZI    #unknown              29.0           467223.4
# 13776            M16A4    #unknown              25.0           162895.7
# 13777     Down and Out    #unknown               3.0           398147.9
# ...                ...         ...               ...                ...
# 13375973         Buggy    #unknown              34.0           324355.5
# 13375975           AKM    #unknown              34.0           326063.4
# 13375980           P92    #unknown              34.0           367533.8
# 13410609        SCAR-L    #unknown              14.0           559155.0
# 13410647  Down and Out    #unknown              14.0           562271.6
#
#           killer_position_y      map  \
# 10606              307978.9  ERANGEL
# ...

# %%
DEATH_Selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 625986 entries, 179 to 13423830
# Data columns (total 13 columns):
# killed_by            625986 non-null object
# killer_name          586737 non-null object
# killer_placement     586737 non-null float64
# killer_position_x    586737 non-null float64
# killer_position_y    586737 non-null float64
# map                  618179 non-null object
# match_id             625986 non-null object
# time                 625986 non-null int64
# victim_name          625986 non-null object
# victim_placement     613749 non-null float64
# victim_position_x    625986 non-null float64
# victim_position_y    625986 non-null float64
# kill_distance        586737 non-null float64
# dtypes: float64(7), int64(1), object(5)
# memory usage: 66.9+ MB

# %%
DEATH_Selected.shape
# Out:
# (625986, 13)

# %%
DEATH_Selected.to_csv('death1.csv')

# %%
AGG_Selected
# Out:
#                               date  game_size  \
# 1061      2017-11-04T07:29:45+0000         50
# 1062      2017-11-04T07:29:45+0000         50
# 1063      2017-11-04T07:29:45+0000         50
# 1064      2017-11-04T07:29:45+0000         50
# 1065      2017-11-04T07:29:45+0000         50
# ...                            ...        ...
# 13845342  2017-12-03T01:19:20+0000         50
# 13845343  2017-12-03T01:19:20+0000         50
# 13845344  2017-12-03T01:19:20+0000         50
# 13845345  2017-12-03T01:19:20+0000         50
# 13845346  2017-12-03T01:19:20+0000         50
#
#                                                    match_id match_mode  \
# 1061      2U4GBNA0YmnXxPYMxq8uh3IZ_R74uPmFVfhHlxf6M3-PzR...        tpp
# 1062      2U4GBNA0YmnXxPYMxq8uh3IZ_R74uPmFVfhHlxf6M3-PzR...        tpp
# 1063      2U4GBNA0YmnXxPYMxq8uh3IZ_R74uPmFVfhHlxf6M3-PzR...        tpp
# 1064      2U4GBNA0YmnXxPYMxq8uh3IZ_R74uPmFVfhHlxf6M3-PzR...        tpp
# ...
